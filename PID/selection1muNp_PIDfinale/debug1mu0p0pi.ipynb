# %%
import numpy as np
import matplotlib.pyplot as plt
# Out:
# Impossibile avviare il kernel. Modulo 'exceptiongroup' mancante. Provare a installare il modulo.
#
# Fare clic <a href='https://aka.ms/kernelFailuresMissingModule'>qui</a> per ulteriori informazioni.

# %%
data_1mu0p0pi = np.genfromtxt(
    '/exp/icarus/app/users/nsommagg/NicolaICARUS/PID/selection1muNp_PIDfinale/debug1mu0p0pi.txt',
    dtype = [
        ('run',int),
        ('evt',int),
        ('slice_index',int),
        ('bestplane',int),
        ('nhit',int),
        ('len',float),
        ('depE',float),
        ('pdg',int),
        ('pred_proba','U100'),
        ('rr','U200'),
        ('dedx','U200')
    ],
    encoding = 'utf-8',
    delimiter = None
    )

rr_1mu0p0pi = [
    np.array([float(x) for x in s.split('_') if x])
    for s in data_1mu0p0pi['rr']
]

dedx_1mu0p0pi = [
    np.array([float(x) for x in s.split('_') if x])
    for s in data_1mu0p0pi['dedx']
]

pred_proba_1mu0p0pi = [
    np.array([float(x) for x in s.split('_') if x])
    for s in data_1mu0p0pi['pred_proba']
]

# %%
data_1muNp = np.genfromtxt(
    '/exp/icarus/app/users/nsommagg/NicolaICARUS/PID/selection1muNp_PIDfinale/debug1muNp.txt',
    dtype = [
        ('run',int),
        ('evt',int),
        ('slice_index',int),
        ('bestplane',int),
        ('nhit',int),
        ('len',float),
        ('depE',float),
        ('pdg',int),
        ('pred_proba','U100'),
        ('rr','U200'),
        ('dedx','U200')
    ],
    encoding = 'utf-8',
    delimiter = None
    )

rr_1muNp = [
    np.array([float(x) for x in s.split('_') if x])
    for s in data_1muNp['rr']
]

dedx_1muNp = [
    np.array([float(x) for x in s.split('_') if x])
    for s in data_1muNp['dedx']
]

pred_proba_1muNp = [
    np.array([float(x) for x in s.split('_') if x])
    for s in data_1muNp['pred_proba']
]
